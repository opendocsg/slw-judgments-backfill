# %%
import sys

sys.path.append('../')

# %%
import os
import subprocess
import shutil
import logging
from typing import Text

from git import Repo
from bs4 import BeautifulSoup
from markdown import markdown

from utils.repopulate import repopulate

# %%
# Helper function

def scrape_judgment(judgment: Text,
                    output_folder: Text):
    """Scrape `judgment` from Singapore Law Watch 
    and save pdfs to `output_folder`"""
    
    # Search SLW for judgment
    url_to_search = ('https://www.singaporelawwatch.sg/Results/PID/426/mcat/498/acat/1/evl/0/nsw/a?EDNSearch=%5b{}%5d+{}+{}'
                    .format(judgment.split('_')[0],
                            judgment.split('_')[1],
                            judgment.split('_')[2]))
    bashCommand = "node ./crawler " + url_to_search + ' ' + output_folder
    process = subprocess.call(bashCommand.split(), stdout=subprocess.PIPE)
    
    if judgment in os.listdir(output_folder):
        return
        
    # Edit search term so that case number ends with a two digit number
    # (e.g. "[2019] SGHC 01" instead of "[2019] SGHC 1")
    judgment_num = int(judgment.split('_')[2])
    if judgment_num <= 9:
        url_to_search = ('https://www.singaporelawwatch.sg/Results/PID/426/mcat/498/acat/1/evl/0/nsw/a?EDNSearch=%5b{}%5d+{}+{}'
                        .format(judgment.split('_')[0],
                                judgment.split('_')[1],
                                f'{judgment_num:02}'))
        bashCommand = "node ./crawler " + url_to_search + ' ' + output_folder
        process = subprocess.call(bashCommand.split(), stdout=subprocess.PIPE)

        # Check if judgment is saved under alternative name
        alt_judgment = '_'.join([judgment.split('_')[0], judgment.split('_')[1], f'{judgment_num:02}'])
        if alt_judgment in os.listdir(output_folder):
            os.rename(os.path.join(output_folder, alt_judgment), os.path.join(output_folder, judgment))
            
    if judgment in os.listdir(output_folder):
        return

    # Edit search term to include judgment name
    path = './../opendoc-supreme-court-judgments'
    with open(os.path.join(path, judgment, 'report.md'), 'r') as f:
        md = f.read()
    title = md.split('#')[1].split('\n')[0].strip().replace('_', '')
    url_to_search = ('https://www.singaporelawwatch.sg/Results/PID/426/mcat/498/acat/1/evl/0/nsw/a?EDNSearch=%5b{}%5d+{}+{}'
                    .format(judgment.split('_')[0],
                            judgment.split('_')[1],
                            judgment.split('_')[2]))
    for word in title.split():
        url_to_search += '+' + word 
    bashCommand = "node ./crawler " + url_to_search + ' ' + output_folder
    process = subprocess.call(bashCommand.split(), stdout=subprocess.PIPE)
    
    if judgment in os.listdir(output_folder):
        return
    
    # Edit search term to judgment name only
    path = './../opendoc-supreme-court-judgments'
    with open(os.path.join(path, judgment, 'report.md'), 'r') as f:
        md = f.read()
    title = md.split('#')[1].split('\n')[0].strip().replace('_', '')
    url_to_search = ('https://www.singaporelawwatch.sg/Results/PID/426/mcat/498/acat/1/evl/0/nsw/a?EDNSearch=')
    for word in title.split():
        url_to_search += '+' + word 

    bashCommand = "node ./crawler " + url_to_search + ' ' + output_folder
    process = subprocess.call(bashCommand.split(), stdout=subprocess.PIPE)

# %%
# Paramaters
num_char_error_allowance = 100

# Config
logging.basicConfig(level=logging.INFO)

# %%
# Pull judgments from github
Repo.clone_from("https://github.com/opendocsg/opendoc-supreme-court-judgments", 
                "opendoc-supreme-court-judgments")

# Pull crawler from github 
Repo.clone_from("https://github.com/opendocsg/slw-judgments-crawler", 
                "slw-judgments-crawler")

# Set up crawler
os.chdir('slw-judgments-crawler/')
bashCommand = "npm install"
process = subprocess.call(bashCommand.split(), stdout=subprocess.PIPE)

# %%
# Get judgments with deleted case numbers 
# (i.e. judgments without case number in subheader)

judgments_without_case_numbers = []
path = './../opendoc-supreme-court-judgments'
for judgment in os.listdir(path):
    file_path = os.path.join(path, judgment, 'report.md')
    if os.path.isfile(file_path):
        with open(file_path, 'r') as f:
            md = f.read()
            if '### \[201' not in md:
                judgments_without_case_numbers.append(judgment)

# %%
# Repopulate judgments

badly_repopulated_judgments = []
judgments_not_found_in_slw = []

for judgment in judgments_without_case_numbers:
    
    logging.info('Repopulating ' + judgment + '...')    
    
    # Create tmp_judgment_dir
    os.mkdir('tmp_judgment_dir')

    # Scrape new judgment using crawler
    scrape_judgment(judgment=judgment, output_folder='tmp_judgment_dir')

    # Repopulate judgment
    if judgment in os.listdir('tmp_judgment_dir'):
        with open(os.path.join(path, judgment, 'report.md'), 'r') as f:
            md = f.read()
        with open(os.path.join('tmp_judgment_dir', judgment, 'report.md'), 'r') as f:
            new_md = f.read()

        repopulated = repopulate(old_md=md, new_md=new_md)  
        repopulated_md = repopulated.get('repopulated_md')
        case_numbers = repopulated.get('case_numbers')

        logging.info('Case numbers added:\n' + '\n'.join(case_numbers))

        # Log when case numbers were added incorrectly
        num_excess_char_added = abs(abs(len(md) - len(repopulated_md)) 
                                    - len(' '.join(case_numbers)))
        if num_excess_char_added > num_char_error_allowance:
            badly_repopulated_judgments.append({'judgment': judgment, 
                                                'num_excess_char': num_excess_char_added})
            logging.warning('Case numbers could have been added incorrectly to ' 
                            + judgment + ' (' 
                            + str(num_excess_char_added) 
                            + ' excess char added)')
            shutil.rmtree('tmp_judgment_dir')   
            continue

        # Overwrite old judgment
        with open(os.path.join('..', 'opendoc-supreme-court-judgments', judgment,'report.md'), 'w') as f:
            f.write(repopulated_md)
        logging.info(judgment + ' overwritten.')
    
    else:
        logging.warning(judgment + ' not found in SLW.')
        judgments_not_found_in_slw.append(judgment)
        
    # Delete tmp_judgment_dir
    shutil.rmtree('tmp_judgment_dir')
# Out:
# INFO:root:Repopulating 2019_SGHC_33...
# INFO:root:Case numbers added:
# [2019] SGHC 33
# [2006] 1 SLR 548
# [2014] 3 SLR 721
# INFO:root:2019_SGHC_33 overwritten.
# INFO:root:Repopulating 2019_SGHC_34...
# INFO:root:Case numbers added:
# [2019] SGHC 34
# [2014] 2 SLR 56
# [2010] 2 SLR 667
# INFO:root:2019_SGHC_34 overwritten.
# INFO:root:Repopulating 2019_SGHC_60...
# INFO:root:Case numbers added:
# [2019] SGHC 60
# [2012] 4 SLR 546
# [2018] 2 SLR 110
# [2007] 3 SLR(R) 537
# [2005] 2 SLR(R) 509
# [2000] 2 SLR(R) 30
# INFO:root:2019_SGHC_60 overwritten.
# INFO:root:Repopulating 2019_SGHC_94...
# INFO:root:Case numbers added:
# [2019] SGHC 94
# [1995] 2 SLR(R) 262
# [1999] 3 SLR(R) 44
# [2011] 2 SLR 47
# [2012] 3 SLR 352
# [2016] 3 SLR 557
# [2019] SGHC 94
# WARNING:root:Case numbers could have been added incorrectly to 2019_SGHC_94 (9381 excess char added)
# INFO:root:Repopulating 2019_SGHC_93...
# INFO:root:Case numbers added:
# [2019] SGHC 93
# [2014] 3 SLR 721
# [2017] 1 SLR 633
# [2019] 1 SLR 113
# INFO:root:2019_SGHC_93 overwritten.
# INFO:root:Repopulating 2019_SGHC_67...
# INFO:root:Case numbers added:
# [2019] SGHC 67
# [2001] 2 SLR(R) 435
# [2008] 2 SLR(R) 909
# [2013] 3 SLR 801
# [2014] 4 SLR 375
# [2013] 4 SLR 308
# [1996] AC 563
# [2013] 1 SLR 1310
# [1976] 1 WLR 13
# [2003] 3 SLR(R) 307
# INFO:root:2019_SGHC_67 overwritten.
# INFO:root:Repopulating 2019_SGHC_58...
# INFO:root:Case numbers added:
# [2019] SGHC 58
# [2017] 4 SLR 66
# [2018] SGHC 253
# INFO:root:2019_SGHC_58 overwritten.
# INFO:root:Repopulating 2019_SGHC_51...
# INFO:root:Case numbers added:
# [2019] SGHC 51
# [2012] 1 SLR 701
# [2005] 2 SLR(R) 594
# [2009] SGHC 115
# [1986] 1 QB 424
# [2000] 1 SLR(R) 553
# [2018] 3 SLR 943
# INFO:root:2019_SGHC_51 overwritten.
# INFO:root:Repopulating 2019_SGHC_2...
# INFO:root:Case numbers added:
# [2019] SGHC 2
# [2004] 3 SLR(R) 316
# [1915] AC 79
# [2015] 3 SLR 732
# [2016] 3 SLR 663
# [2016] SGHC 144
# [2018] 3 SLR 534
# [2017] SGHC 22
# [2018] SGHC 166
# [2018] SGHC 263
# [1905] AC 6
# [1912] AC 394
# [2017] 2 SLR 129
# [2008] 2 SLR(R) 623
# [2018] 2 SLR 199
# INFO:root:2019_SGHC_2 overwritten.
# INFO:root:Repopulating 2019_SGHC_56...
# INFO:root:Case numbers added:
# [2019] SGHC 56
# [2010] 2 SLR 776
# [2010] SGHC 268
# [2015] 5 SLR 178
# [2005] 1 SLR(R) 661
# INFO:root:2019_SGHC_56 overwritten.
# INFO:root:Repopulating 2019_SGHC_69...
# INFO:root:Case numbers added:
# [2019] SGHC 69
# [2010] 1 SLR 573
# [2007] 1 SLR(R) 597
# [2008] 3 SLR(R) 871
# [2013] 4 SLR 947
# [2010] SGHC 231
# INFO:root:2019_SGHC_69 overwritten.
# INFO:root:Repopulating 2019_SGHC_5...
# INFO:root:Case numbers added:
# [2019] SGHC 5
# [2018] SGDC 110
# [2017] 3 SLR 682
# [2018] SGHC 236
# [2011] 2 SLR 1057
# INFO:root:2019_SGHC_5 overwritten.
# INFO:root:Repopulating 2019_SGHC_35...
# INFO:root:Case numbers added:
# [2019] SGHC 35
# [2017] 2 SLR 265
# [2004] 3 SLR(R) 12
# [2017] 2 SLR 997
# [1997] 2 SLR(R) 862
# [2016] 3 SLR 1195
# INFO:root:2019_SGHC_35 overwritten.
# INFO:root:Repopulating 2019_SGHC_32...
# INFO:root:Case numbers added:
# [2019] SGHC 32
# [2013] 3 SLR 380
# [2019] SGHC 32
# INFO:root:2019_SGHC_32 overwritten.
# INFO:root:Repopulating 2019_SGHC(I)_1...
# INFO:root:Case numbers added:
# [2019] SGHC(I) 1
# [2019] SGHC(I) 1
# INFO:root:2019_SGHC(I)_1 overwritten.
# INFO:root:Repopulating 2019_SGHC_57...
# INFO:root:Case numbers added:
# [2019] SGHC 57
# [2018] 2 SLR 588
# [2005] 4 SLR(R) 417
# [2012] SGHC 135
# [1999] 2 SLR(R) 107
# [2018] 4 SLR 473
# [1922] 1 AC 129
# [1949] 1 AC 236
# [2004] 4 SLR(R) 89
# [2019] SGHC 57
# WARNING:root:Case numbers could have been added incorrectly to 2019_SGHC_57 (48102 excess char added)
# INFO:root:Repopulating 2019_SGHC_68...
# INFO:root:Case numbers added:
# [2019] SGHC 68
# [2016] 2 SLR 366
# [1898] 2 QB 380
# [1923] 2 KB 857
# [2006] 1 SLR(R) 112
# [1983] 1 QB 759
# (1991) 3 SAcLJ 167
# [2003] 1 SLR(R) 382
# [2017] 1 SLR 141
# [1997] 2 SLR(R) 427
# [2012] 4 SLR 1206
# [2017] SGHC 78
# [2015] 5 SLR 962
# [2001] 1 SLR(R) 798
# [2000] 2 SLR(R) 407
# [2015] SGHC 30
# [2013] 4 SLR 193
# [1994] 3 SLR(R) 250
# [2017] 5 SLR 203
# [2013] 4 SLR 1023
# [2018] SGHC 215
# [2014] 2 SLR 1165
# INFO:root:2019_SGHC_68 overwritten.
# INFO:root:Repopulating 2019_SGHC_4...
# INFO:root:Case numbers added:
# [2019] SGHC 4
# [1893] AC 22
# [2011] SGHC 82
# [2018] 1 SLR 170
# [2016] 1 SLR 1069
# [2008] 3 SLR(R) 1029
# [2013] 4 SLR 193
# [2017] 1 SLR 219
# [2013] 4 SLR 193
# [2018] 3 SLR 1269
# [2017] SGHC 72
# [1997] 1 SLR(R) 555
# [2009] 1 SLR(R) 385
# [1999] 3 SLR(R) 518
# [1997] 1 SLR(R) 907
# [1997] 2 SLR(R) 427
# INFO:root:2019_SGHC_4 overwritten.
# INFO:root:Repopulating 2019_SGHC_50...
# INFO:root:Case numbers added:
# [2019] SGHC 50
# INFO:root:2019_SGHC_50 overwritten.
# INFO:root:Repopulating 2019_SGHC_3...
# INFO:root:Case numbers added:
# [2019] SGHC 3
# [2013] 4 SLR 694
# [2015] 2 SLR 931
# [2015] 5 SLR 989
# [2014] 1 SLR 694
# [2013] 3 SLR 103
# [2008] 2 SLR(R) 597
# [2017] 2 SLR 413
# [2009] 3 SLR(R) 109
# [2009] 2 SLR(R) 1
# [2017] 4 SLR 74
# [1967] 2 AC 46
# [2009] 3 SLR(R) 724
# [2019] SGHC 3
# WARNING:root:Case numbers could have been added incorrectly to 2019_SGHC_3 (84226 excess char added)
# INFO:root:Repopulating 2019_SGHC_66...
# INFO:root:Case numbers added:
# [2019] SGHC 66
# [1997] 3 SLR(R) 649
# [2015] 2 SLR 540
# [2018] 2 SLR 866
# [2018] 2 SLR 1242
# [2013] SGHC 274
# [2010] 3 SLR 110
# [2005] QB 946
# [2015] 1 SLR 752
# [2016] 4 SLR 977
# [2010] 4 SLR 357
# [1997] 3 SLR(R) 576
# [2010] 1 SLR 52
# [2005] 2 SLR(R) 712
# [2018] 3 SLR 117
# [2019] SGHC 36
# [2018] 3 SLR 498
# [1988] 2 SLR(R) 252
# [1995] 3 SLR(R) 38
# INFO:root:2019_SGHC_66 overwritten.
# INFO:root:Repopulating 2019_SGHC_92...
# INFO:root:Case numbers added:
# [2019] SGHC 92
# [2008] 2 SLR(R) 955
# [2001] 2 SLR(R) 398
# [1998] 3 SLR(R) 490
# [2000] 1 SLR(R) 466
# [2018] 5 SLR 1261
# [2010] 3 SLR 390
# [2017] 4 SLR 1369
# [2016] 5 SLR 1141
# [2018] 5 SLR 1068
# [2007] 3 SLR(R) 477
# [2009] 4 SLR(R) 674
# [2016] 5 SLR 1131
# [2006] 4 SLR(R) 308
# [2013] 3 SLR 221
# [2001] 1 SLR(R) 65
# [2004] 2 SLR(R) 447
# [2007] 3 SLR(R) 401
# [2004] 2 SLR(R) 447
# INFO:root:2019_SGHC_92 overwritten.
# INFO:root:Repopulating 2019_SGHCR_6...
# INFO:root:Case numbers added:
# [2019] SGHCR 6
# [2016] 2 SLR 50
# [2015] 2 SLR 540
# [1984] 1 WLR 485
# [1921] 3 KB 302
# [1908] 1 KB 968
# [1965] 1 QB 560
# (2016) 28 SAc LJ 472
# INFO:root:2019_SGHCR_6 overwritten.
# INFO:root:Repopulating 2019_SGHC_59...
# INFO:root:Case numbers added:
# [2019] SGHC 59
# [2009] 2 SLR(R) 332
# [2011] 2 SLR 758
# [2011] 2 SLR 232
# [2018] 1 SLR 180
# INFO:root:2019_SGHC_59 overwritten.
# INFO:root:Repopulating 2019_SGHC_95...
# INFO:root:Case numbers added:
# [2019] SGHC 95
# [2015] 4 SLR 529
# [2006] 4 SLR(R) 521
# [2016] SGVRB 1
# [2017] SGVRB 1
# [2010] 1 SLR 286
# [2008] 3 SLR(R) 569
# [1902] AC 157
# [2012] 3 SLR 933
# [1993] 2 SLR(R) 354
# [1902] AC 157
# [1997] 1 WLR 687
# [1954] 1 QB 70
# [1988] 1 SLR(R) 141
# [1903] 2 KB 135
# [1957] AC 362
# [1966] 2 QB 484
# [2003] 1 WLR 2423
# [2013] 2 SLR 173
# [2013] 3 SLR 339
# [1937] 2 KB 445
# [1920] AC 273
# [1900] AC 150
# [1903] AC 426
# [2007] 3 SLR(R) 326
# [2006] SGVRB 2
# INFO:root:2019_SGHC_95 overwritten.
# INFO:root:Repopulating 2019_SGHCR_1...
# INFO:root:Case numbers added:
# [2019] SGHCR 1
# [2008] 4 SLR(R) 224
# [1977] 1 WLR 899
# [2006] 4 SLR(R) 817
# [2009] 1 WLR 751
# [2014] SGHC 219
# [2008] SGHC 230
# [2011] SGHC 11
# [1999] 1 SLR(R) 112
# [2017] SGHC 15
# [2016] 3 SLR 621
# [2004] 1 SLR(R) 434
# [2011] SGHC 228
# [2013] SGHCR 10
# INFO:root:2019_SGHCR_1 overwritten.
# INFO:root:Repopulating 2019_SGHC_61...
# INFO:root:Case numbers added:
# [2019] SGHC 61
# [1992] 2 SLR(R) 382
# [2015] 5 SLR 1422
# [2018] SGHC 264
# [2007] 2 SLR(R) 655
# [2004] 3 SLR(R) 534
# [1992] SGHC 321
# [2007] 3 SLR(R) 265
# [2015] 5 SLR 1187
# [2013] 3 SLR 1017
# (1887) 19 QBD 647
# [2011] 3 SLR 337
# [2001] 2 AC 710
# [1988] 1 SLR(R) 220
# [2017] 6 MLJ 564
# [2015] 3 MLJ 791
# [1992] 3 SLR(R) 307
# [2018] SGHC 215
# [1990] 1 SLR(R) 413
# [2018] 2 SLR 129
# [2015] 2 SLR 686
# [2016] 4 SLR 1177
# [2016] 2 SLR 737
# [2018] 2 SLR 866
# INFO:root:2019_SGHC_61 overwritten.
# INFO:root:Repopulating 2018_SGHC_271...
# INFO:root:Case numbers added:
# [2018] SGHC 271
# [2015] 2 SLR 686
# [2002] 2 AC 164
# [2017] 1 SLR 654
# [2018] 2 SLR 655
# [2015] 1 SLR 496
# [2007] 1 WLR 2351
# [2018] SGCA 63
# [1991] 1 WLR 461
# [2018] SGHC 271
# WARNING:root:Case numbers could have been added incorrectly to 2018_SGHC_271 (145933 excess char added)
# INFO:root:Repopulating 2018_SGHC_276...
# INFO:root:Case numbers added:
# [2018] SGHC 276
# [2017] SGFC 40
# [2018] 3 SLR 1433
# [2018] 1 SLR 1015
# [2000] SGHC 31
# [2007] 1 SLR(R) 265
# [2008] 2 SLR(R) 108
# [2014] 3 SLR 1048
# [2011] SGHC 64
# [2018] SGHC 162
# [2008] 4 SLR(R) 783
# [1999] 3 SLR(R) 410
# INFO:root:2018_SGHC_276 overwritten.
# INFO:root:Repopulating 2018_SGHC_278...
# INFO:root:Case numbers added:
# [2018] SGHC 278
# [2001] 2 SLR(R) 435
# [2016] 5 SLR 335
# [2003] 3 SLR(R) 307
# [2017] 1 SLR 219
# [2008] 3 SLR(R) 1029
# [1997] 2 SLR(R) 113
# INFO:root:2018_SGHC_278 overwritten.
# INFO:root:Repopulating 2018_SGHCF_21...
# INFO:root:Case numbers added:
# [2018] SGHCF 21
# [2018] SGFC 6
# [2017] 5 SLR 299
# [1994] 2 SLR(R) 99
# [1968] 2 QB 587
# [2016] 3 SLR 329
# [1987] SLR(R) 123
# [2017] 2 SLR 707
# [1999] 1 SLR(R) 1053
# [2015] 4 SLR 81
# INFO:root:2018_SGHCF_21 overwritten.
# INFO:root:Repopulating 2018_SGHCF_19...
# INFO:root:Case numbers added:
# [2018] SGHCF 19
# [2018] SGFC 32
# [2015] 3 SLR 973
# [2015] 2 SLR 879
# [2005] 3 SLR(R) 690
# [2007] 3 SLR(R) 233
# [2018] 2 SLR 833
# [2012] 3 SLR 627
# INFO:root:2018_SGHCF_19 overwritten.
# INFO:root:Repopulating 2019_SGHCF_5...
# INFO:root:Case numbers added:
# [2019] SGHCF 5
# [2016] 3 SLR 1172
# [2007] 3 SLR(R) 743
# [2013] 1 SLR 476
# [2013] SGHC 91
# [2015] SGHCF 11
# [2013] SGHC 50
# [2018] SGHCF 1
# [2007] 2 SLR(R) 729
# [2016] 2 SLR 686
# [1996] 1 SLR(R) 906
# [2016] 4 SLR 145
# [2017] SGCA 34
# [2016] 2 SLR 686
# [2012] 4 SLR 405
# [2017] 1 SLR 609
# [2015] 4 SLR 1043
# [2015] SGCA 52
# [2016] 3 SLR 717
# [2009] SGDC 256
# [2009] SGHC 247
# [2014] 2 SLR 1320
# [2017] SGFC 149
# [2007] SGCA 21
# INFO:root:2019_SGHCF_5 overwritten.
# INFO:root:Repopulating 2019_SGHCF_2...
# INFO:root:Case numbers added:
# [2019] SGHCF 2
# [2018] SGFC 44
# [2010] 4 SLR 373
# [1999] 2 SLR(R) 166
# [2009] 3 SLR(R) 631
# [2003] 2 MLJ 97
# [2011] Ch 380
# [2002] 1 WLR 1097
# [2016] 3 SLR 405
# [2009] 3 SLR(R) 1079
# [2010] 4 SLR 93
# [2002] 2 SLR(R) 490
# [1999] 2 SLR(R) 1145
# [2015] SGHC 205
# [2017] SGHC 316
# [2000] 1 SLR(R) 145
# [2019] SGHCF 2
# WARNING:root:Case numbers could have been added incorrectly to 2019_SGHCF_2 (75314 excess char added)
# INFO:root:Repopulating 2018_SGHC_279...
# INFO:root:Case numbers added:
# [2018] SGHC 279
# [2018] 1 SLR 610
# INFO:root:2018_SGHC_279 overwritten.
# INFO:root:Repopulating 2018_SGHC_277...
# INFO:root:Case numbers added:
# [2018] SGHC 277
# [2016] 4 SLR 604
# INFO:root:2018_SGHC_277 overwritten.
# INFO:root:Repopulating 2018_SGHC_270...
# INFO:root:Case numbers added:
# [2018] SGHC 270
# [1997] 3 SLR(R) 649
# [2012] 4 SLR 546
# [1992] SGHC 190
# [2002] 1 SLR(R) 418
# [2012] SGSTB 2
# [2018] SGHC 270
# WARNING:root:Case numbers could have been added incorrectly to 2018_SGHC_270 (15748 excess char added)
# INFO:root:Repopulating 2019_SGHCF_3...
# INFO:root:Case numbers added:
# [2019] SGHCF 3
# [2017] SGFC 40
# [2018] SGHC 276
# [2007] 3 SLR(R) 743
# [2015] 4 SLR 1043
# [2017] 1 SLR 609
# [2011] 2 SLR 1157
# [2016] 2 SLR 686
# [2017] SGCA 34
# [2016] 4 SLR 145
# [2016] 2 SLR 686
# [2013] SGHC 50
# [2006] SGHC 177
# [2009] SGHC 246
# [1981] 3 WLR 284
# [1976] 3 WLR 572
# [2016] 3 SLR 717
# INFO:root:2019_SGHCF_3 overwritten.
# INFO:root:Repopulating 2019_SGHCF_4...
# INFO:root:Case numbers added:
# [2019] SGHCF 4
# [2008] 2 SLR(R) 108
# [1993] 3 SLR(R) 491
# [2015] 4 SLR 1043
# [2016] 3 SLR 1172
# [2017] SGCA 34
# [2007] 3 SLR(R) 743
# [2011] 2 SLR 1157
# [1994] 2 SLR(R) 133
# [2018] SGHCF 11
# [2012] 2 SLR 506
# [2016] SGCA 2
# INFO:root:2019_SGHCF_4 overwritten.
# INFO:root:Repopulating 2018_SGHCF_18...
# INFO:root:Case numbers added:
# [2018] SGHCF 18
# [2018] SGFC 20
# [1970] 1 AC 668
# [1997] 3 SLR(R) 430
# [2003] 1 SLR(R) 502
# [1990] 2 SLR(R) 157
# [1963] 1 WLR 231
# [1959] 1 QB 229
# [2015] 3 SLR 973
# [1952] 2 QB 561
# [2004] 1 AC 523
# [2006] 1 WLR 2305
# [2017] SGHCF 21
# [1967] 1 WLR 34
# [2015] Fam 186
# [2009] 3 SLR(R) 573
# (1880) 5 App Cas 214
# [1971] 1 WLR 1227
# [1977] AC 547
# [2017] 1 SLR 918
# [2018] 2 SLR 866
# [2006] 4 SLR(R) 884
# [2013] 3 SLR 354
# [2018] 1 SLR 363
# [1981] 1 QB 758
# [1991] 2 QB 393
# [2011] 2 AC 304
# [1996] 3 SLR(R) 390
# [2010] 1 SLR 52
# [2015] 1 SLR 26
# (2017) 29 SAcLJ 800
# [2016] 1 SLR 779
# [1996] QB 517
# [1938] AC 1
# [1988] 1 SLR(R) 530
# [2017] 2 SLR 850
# [2017] 1 SLR 373
# [2017] 5 SLR 424
# [1944] 1 AC 111
# [2012] 4 SLR 1267
# (2018) 30 SAcLJ 455
# INFO:root:2018_SGHCF_18 overwritten.
# INFO:root:Repopulating 2018_SGHCF_20...
# INFO:root:Case numbers added:
# [2018] SGHCF 20
# [2004] 4 SLR(R) 784
# [1996] 3 SLR(R) 83
# [1999] 2 SLR(R) 392
# [2018] 3 SLR 1433
# [2010] HKCFI 713
# [2016] 4 SLR 145
# (2011) 12 SAL Ann Rev 298
# [2003] 1 SLR(R) 502
# [1997] 3 SLR(R) 430
# [1984] 1 WLR 156
# [1967] 1 WLR 396
# [2016] HKCA 515
# INFO:root:2018_SGHCF_20 overwritten.
# INFO:root:Repopulating 2018_SGCA_87...
# INFO:root:Case numbers added:
# [2018] SGCA 87
# [2017] SGHC 233
# [2005] 1 SLR(R) 103
# [1993] 3 SLR(R) 656
# [2009] 4 SLR(R) 946
# [1995] 1 SLR(R) 32
# [1993] 3 SLR(R) 143
# [1999] 1 SLR(R) 931
# [2003] SGHC 60
# [2018] SGCA 59
# [2006] 4 SLR(R) 45
# [2018] 1 SLR 610
# [2012] SGCA 18
# [1981] 1 QB 720
# [2015] SGCA 33
# [2002] 1 SLR(R) 1166
# [1999] 3 SLR(R) 273
# [1995] 2 SLR(R) 806
# [2011] 3 SLR 1205
# [2002] 1 SLR(R) 1166
# [1969] 2 MLJ 63
# [1998] 3 SLR(R) 281
# [1993] 3 SLR(R) 302
# [2011] SGCA 52
# [1993] 3 SLR(R) 302
# INFO:root:2018_SGCA_87 overwritten.
# INFO:root:Repopulating 2018_SGHC_264...
# INFO:root:Case numbers added:
# [2018] SGHC 264
# [2004] 4 SLR(R) 574
# [1996] 2 SLR(R) 650
# [2015] 5 SLR 1422
# [2015] 5 SLR 1187
# [2016] 2 SLR 1083
# [2007] 4 SLR(R) 513
# [1982] QB 84
# [2006] 2 SLR(R) 195
# [2007] 4 SLR(R) 413
# [2007] 4 SLR(R) 100
# [2014] 3 SLR 967
# [2016] 5 SLR 815
# [2013] 4 SLR 886
# [1964] AC 465
# [2014] 4 SLR 375
# [2011] 2 SLR 146
# [2013] 4 SLR 308
# [2013] 2 AC 415
# INFO:root:2018_SGHC_264 overwritten.
# INFO:root:Repopulating 2019_SGHC_88...
# INFO:root:Case numbers added:
# [2019] SGHC 88
# [2018] SGHC 92
# [2018] SGCA(I) 7
# [2018] SGDC 309
# [2017] 3 SLR 501
# [1997] 2 SLR(R) 862
# [2006] 1 SLR(R) 135
# [2019] SGHC 36
# [2018] SGHC 92
# WARNING:root:Case numbers could have been added incorrectly to 2019_SGHC_88 (10709 excess char added)
# INFO:root:Repopulating 2019_SGCA_17...
# INFO:root:Case numbers added:
# [2019] SGCA 17
# [2011] 2 SLR 1189
# [2006] 4 SLR(R) 45
# [2018] 2 SLR 1087
# [2012] 3 SLR 527
# [2017] SGHC 290
# [2017] 1 SLR 633
# [1995] 3 SLR(R) 689
# [2018] 1 SLR 610
# [2006] 1 SLR(R) 548
# [2011] SGCA 38
# [2017] SGCA 41
# [1999] 2 SLR(R) 314
# [2018] 2 SLR 1119
# [1995] 1 SLR(R) 778
# [2017] 1 SLR 257
# [2011] 4 SLR 1156
# [1994] 3 SLR(R) 375
# [2001] SGCA 32
# [1987] 2 WLR 765
# [2017] 2 SLR 850
# [2012] SGCA 18
# [2016] 1 SLR 753
# [2017] 5 SLR 1160
# INFO:root:2019_SGCA_17 overwritten.
# INFO:root:Repopulating 2019_SGHC_43...
# INFO:root:Case numbers added:
# [2019] SGHC 43
# [2017] SGHCR 8
# [2017] 1 SLR 219
# [2018] SGHC 24
# [1962] 1 WLR 832
# [2018] SGHC 264
# [2015] 2 SLR 686
# [2014] 1 SLR 860
# [2016] 3 SLR 845
# [2014] 3 SLR 329
# [2009] 3 SLR(R) 109
# [2017] 2 SLR 592
# [2018] 2 SLR 333
# [2017] 3 SLR 839
# [2014] 1 SLR 847
# [2015] 1 SLR 496
# [2013] SGHC 96
# [2014] 1 SLR 245
# [2016] 4 SLR 472
# [2018] SGHC 239
# [1995] 1 WLR 1602
# [2005] 1 SLR(R) 661
# [2015] SGHC 213
# [2007] 4 SLR(R) 460
# [1911] 2 KB 786
# [2007] 2 SLR(R) 597
# [2018] SGHC 271
# [2014] 3 WLR 1367
# [1996] AC 421
# [2006] 3 SLR(R) 827
# [2018] 1 SLR 763
# INFO:root:2019_SGHC_43 overwritten.
# INFO:root:Repopulating 2019_SGCA_10...
# INFO:root:Case numbers added:
# [2019] SGCA 10
# [1999] 1 AC 119
# [1987] 1 AC 871
# [2009] 4 SLR(R) 428
# [1997] 2 SLR(R) 148
# [1994] 2 SLR(R) 898
# [2011] 4 SLR 503
# [2017] 4 SLR 1232
# [2018] SGHC 90
# [2013] 3 SLR 409
# [2013] 1 WLR 1889
# [2016] 1 WLR 2231
# [2010] 1 WLR 1023
# [2011] 2 SLR 96
# [2009] QB 503
# [1928] 2 KB 144
# [2014] 1 WLR 4360
# [1996] 2 SLR(R) 80
# [2014] 1 SLR 130
# [2017] 3 SLR 357
# [2016] 1 SLR 966
# [2013] 1 SLR 125
# [2012] 4 SLR 476
# INFO:root:2019_SGCA_10 overwritten.
# INFO:root:Repopulating 2019_SGHC_44...
# INFO:root:Case numbers added:
# [2019] SGHC 44
# [2014] 3 SLR 721
# [1997] 2 SLR(R) 796
# [1998] 3 SLR(R) 142
# [1998] 3 SLR(R) 281
# [2012] SGCA 18
# [2016] 1 SLR 753
# [2018] 1 SLR 610
# [2016] SGHC 102
# [2018] SGHC 161
# [2008] 1 SLR(R) 1
# [2018] SGCA 87
# [2007] 2 SLR(R) 983
# INFO:root:2019_SGHC_44 overwritten.
# INFO:root:Repopulating 2019_SGCA_26...
# INFO:root:Case numbers added:
# [2019] SGCA 26
# [2018] SGHC 156
# [2017] 1 SLR 654
# [2012] 2 SLR 672
# [2007] 1 WLR 591
# INFO:root:2019_SGCA_26 overwritten.
# INFO:root:Repopulating 2019_SGHC_72...
# INFO:root:Case numbers added:
# [2019] SGHC 72
# [2002] 2 SLR(R) 821
# [2018] 1 SLR 659
# [2018] 5 SLR 549
# [2014] 1 SLR 245
# [2013] 1 SLR 1095
# INFO:root:2019_SGHC_72 overwritten.
# INFO:root:Repopulating 2019_SGCA_19...
# INFO:root:Case numbers added:
# [2019] SGCA 19
# [2017] SGHC 169
# [2018] 2 SLR 788
# [2018] SGHC 54
# [2012] NSWSC 667
# [2018] SGHC 262
# [2018] 4 SLR 425
# [1998] 2 SLR(R) 154
# [2009] 3 SLR(R) 840
# [2010] 1 SLR 241
# [2011] SGHC 43
# [2006] 4 SLR(R) 745
# [2013] NSWSC 1119
# [1986] Ch. 658
# [2010] 2 SLR 209
# [2014] SGHC 224
# [2010] 2 SLR 776
# INFO:root:2019_SGCA_19 overwritten.
# INFO:root:Repopulating 2019_SGHC_86...
# INFO:root:Case numbers added:
# [2019] SGHC 86
# [2008] 3 SLR(R) 1029
# [2013] 4 SLR 193
# [2018] 1 SLR 170
# [2019] 1 SLR 30
# [2019] 1 SLR 414
# [2014] 2 SLR 905
# INFO:root:2019_SGHC_86 overwritten.
# INFO:root:Repopulating 2019_SGCA_21...
# INFO:root:Case numbers added:
# [2019] SGCA 21
# [2015] SGDC 300
# [2016] 3 SLR 965
# [2016] SGDC 222
# [2017] 4 SLR 421
# [2017] 2 SLR 850
# [2018] 1 SLR 659
# [1964] 1 AC 763
# [1969] 2 MLJ 250
# [2010] 3 SLR 489
# [2007] 4 SLR(R) 183
# [2016] 4 SLR 604
# [2019] SGCA 21
# WARNING:root:Case numbers could have been added incorrectly to 2019_SGCA_21 (94272 excess char added)
# INFO:root:Repopulating 2019_SGHC_81...
# INFO:root:Case numbers added:
# [2019] SGHC 81
# [2016] 5 SLR 977
# [2014] 2 SLR 446
# [2018] SGHC 250
# [2015] Ch 589
# [2007] 2 SLR(R) 268
# [2018] 2 SLR 1271
# [2009] 4 SLR(R) 732
# [1999] 3 SLR(R) 432
# [2011] 4 SLR 997
# [1983] 1 A.C. 854
# [2018] 4 SLR 1086
# [1990] 1 WLR 1320
# [2015] 5 SLR 962
# [2012] 1 SLR 32
# [2011] 1 SLR 524
# [2015] 1 SLR 875
# [2018] 2 WLR 1603
# [2002] 2 SLR(R) 1119
# [2003] 1 SLR(R) 471
# [2009] 2 SLR(R) 949
# INFO:root:2019_SGHC_81 overwritten.
# INFO:root:Repopulating 2019_SGHC_75...
# INFO:root:Case numbers added:
# [2019] SGHC 75
# [2016] SGHC 217
# INFO:root:2019_SGHC_75 overwritten.
# INFO:root:Repopulating 2019_SGCA_7...
# INFO:root:Case numbers added:
# [2019] SGCA 7
# [2017] SGHC 288
# [2018] 1 SLR 239
# [2003] 1 SLR(R) 791
# [2013] Ch 23
# [2009] 4 SLR(R) 1101
# [2008] 3 SLR(R) 1029
# [2015] 5 SLR 1187
# INFO:root:2019_SGCA_7 overwritten.
# INFO:root:Repopulating 2019_SGHC_21...
# INFO:root:Case numbers added:
# [2019] SGHC 21
# [2015] 5 SLR 522
# INFO:root:2019_SGHC_21 overwritten.
# INFO:root:Repopulating 2019_SGHC_26...
# INFO:root:Case numbers added:
# [2019] SGHC 26
# INFO:root:2019_SGHC_26 overwritten.
# INFO:root:Repopulating 2019_SGHC_19...
# INFO:root:Case numbers added:
# [2019] SGHC 19
# [1987] SLR(R) 349
# [2018] 1 SLR 363
# INFO:root:2019_SGHC_19 overwritten.
# INFO:root:Repopulating 2019_SGHC_10...
# INFO:root:Case numbers added:
# [2019] SGHC 10
# INFO:root:2019_SGHC_10 overwritten.
# INFO:root:Repopulating 2019_SGCA_9...
# INFO:root:Case numbers added:
# [2019] SGCA 9
# [2018] 1 SLR 449
# [2017] 3 SLR 66
# INFO:root:2019_SGCA_9 overwritten.
# INFO:root:Repopulating 2019_SGHC_17...
# INFO:root:Case numbers added:
# [2019] SGHC 17
# [2017] 1 SLR 257
# [1991] 1 SLR(R) 111
# INFO:root:2019_SGHC_17 overwritten.
# INFO:root:Repopulating 2019_SGHC_28...
# INFO:root:Case numbers added:
# [2019] SGHC 28
# [2005] 2 SLR(R) 613
# [2017] 2 SLR 1074
# [2016] 4 SLR 373
# [2006] 2 WLR 428
# [2014] 4 SLR 931
# [1969] 2 QB 173
# [2016] 4 SLR 521
# [2011] 2 SLR 146
# [2012] 2 SLR 549
# [2014] 2 SLR 360
# [2014] SGHC 177
# [2018] SGHC 22
# [2018] 1 SLR 76
# [1967] AC 617
# [1893] 2 Ch. 588
# [2006] 3 SLR(R) 116
# [1994] 2 AC 264
# [2007] SGHC 122
# [2004] 2 AC 1
# [2011] SGHC 108
# INFO:root:2019_SGHC_28 overwritten.
# INFO:root:Repopulating 2019_SGCA_20...
# INFO:root:Case numbers added:
# [2019] SGCA 20
# [2018] SGCA 85
# [2017] 2 SLR 672
# [2014] 1 SLR 345
# [2013] 2 SLR 246
# [2018] 1 SLR 76
# [2019] SGCA 14
# [2017] 1 SLR 312
# [2010] 4 SLR 331
# [2011] 3 SLR 778
# [2016] 3 SLR 1
# [2017] 2 SLR 342
# [1999] 2 SLR(R) 592
# [2007] 2 SLR(R) 518
# [1936] AC 322
# [2009] 1 SLR(R) 1103
# [1974] AC 273
# [1972] 2 QB 52
# [2007] 2 SLR(R) 518
# [2006] 2 SLR(R) 650
# [2009] 1 SLR(R) 1103
# [1922] 1 KB 95
# [2014] 3 SLR 381
# [1984] AC 50
# [2013] 3 SLR 258
# [1990] 2 SLR(R) 348
# [1999] 2 AC 294
# [1991] 1 SLR(R) 85
# [1995] 1 SLR(R) 199
# [2015] 2 SLR 420
# [1994] 1 AC 486
# [2016] 2 SLR 1
# [1999] FCA 633
# [2012] FCA 1323
# [2009] FCA 735
# [1892] 1 QB 321
# [2014] 4 SLR 500
# [1999] 3 SLR(R) 1156
# [2018] 1 SLR 659
# WARNING:root:Case numbers could have been added incorrectly to 2019_SGCA_20 (45564 excess char added)
# INFO:root:Repopulating 2019_SGHC_74...
# INFO:root:Case numbers added:
# [2019] SGHC 74
# [2002] SGHC 132
# [2004] 3 SLR(R) 25
# INFO:root:2019_SGHC_74 overwritten.
# INFO:root:Repopulating 2019_SGHC_80...
# INFO:root:Case numbers added:
# [2019] SGHC 80
# [2011] 1 SLR 1
# [2008] 3 SLR(R) 648
# [2009] 4 SLR(R) 92
# [2016] 4 SLR 1065
# [2019] 3 SLR 305
# [2015] 5 SLR 689
# [2012] 1 SLR 15
# [2010] 2 SLR 1113
# [2019] SGHC 80
# WARNING:root:Case numbers could have been added incorrectly to 2019_SGHC_80 (31018 excess char added)
# INFO:root:Repopulating 2019_SGCA_18...
# INFO:root:Case numbers added:
# [2019] SGCA 18
# [2018] SGHC 88
# [2006] 3 SLR(R) 827
# [2017] 1 SLR 95
# [2008] 4 SLR(R) 362
# [2007] 1 SLR(R) 46
# [1999] 1 WLR 1092
# [1990] 2 SLR(R) 691
# [2018] 1 SLR 763
# [2005] 2 SLR(R) 56
# INFO:root:2019_SGCA_18 overwritten.
# INFO:root:Repopulating 2019_SGHC_87...
# INFO:root:Case numbers added:
# [2019] SGHC 87
# [2008] 3 SLR(R) 1029
# [2016] 3 SLR 1280
# [2003] NSWSC 1004
# [2014] 3 SLR 609
# [2018] 1 SLR 363
# [1991] 1 SLR(R) 164
# [2014] 3 SLR 524
# [2017] 4 SLR 983
# [1906] 1 KB 584
# [2010] 2 SLR 1154
# [1997] 3 SLR(R) 906
# [1932] AC 452
# [1996] 1 SLR(R) 397
# [1993] 1 SLR(R) 609
# [2015] SGHC 78
# [2019] SGHC 87
# WARNING:root:Case numbers could have been added incorrectly to 2019_SGHC_87 (23151 excess char added)
# INFO:root:Repopulating 2019_SGHC_73...
# INFO:root:Case numbers added:
# [2019] SGHC 73
# [2017] SGCA 21
# [2018] SGCA 79
# [2018] 1 SLR 180
# [2018] SGCA 79
# [2013] 2 SLR 524
# [2014] 2 SLR 191
# [2002] 2 SLR(R) 1083
# [1998] 2 SLR(R) 576
# INFO:root:2019_SGHC_73 overwritten.
# INFO:root:Repopulating 2019_SGCA_11...
# INFO:root:Case numbers added:
# [2019] SGCA 11
# [2018] SGHC 172
# [2014] 4 SLR 500
# [2008] 2 SLR(R) 491
# [1987] AC 460
# [2008] HKCA 255
# [2018] 1 SLR 76
# [2010] 3 SLR 179
# [2008] 4 SLR(R) 460
# [2003] 4 SLR(R) 499
# [2017] 1 SLR 312
# [2005] 1 SLR(R) 168
# [2007] 1 SLR(R) 967
# [2008] 2 SLR(R) 857
# [2001] 2 SLR(R) 777
# [2018] 2 SLR 1271
# [2012] 2 SLR 519
# (2005) 17 SAcLJ 306
# [2011] 4 SLR 503
# [1999] 2 SLR(R) 632
# [2013] 3 SLR 409
# [1996] SGHC 285
# [1990] 3 WLR 688
# [2014] 4 SLR 1042
# [2001] 2 SLR(R) 371
# [2002] 1 SLR(R) 485
# [2004] 1 SLR(R) 6
# [2004] 4 SLR(R) 548
# [1990] 1 SLR(R) 504
# [1992] 1 SLR(R) 912
# [1994] 2 SLR(R) 511
# [2013] 4 SLR 1097
# [2007] 1 SLR(R) 377
# [2011] 1 SLR 391
# [2014] 3 SLR 1161
# [1995] 3 SLR(R) 941
# [2008] 4 SLR(R) 994
# INFO:root:2019_SGCA_11 overwritten.
# INFO:root:Repopulating 2019_SGHC_45...
# INFO:root:Case numbers added:
# [2019] SGHC 45
# [1971] AC 1004
# [1992] 3 SLR(R) 855
# [2015] 5 SLR 62
# [2002] 2 AC 773
# [1911] 1 KB 489
# [2012] 4 SLR 546
# [1997] 1 SLR(R) 751
# [2017] 1 SLR 141
# [2006] 4 SLR(R) 308
# INFO:root:2019_SGHC_45 overwritten.
# INFO:root:Repopulating 2019_SGHC_89...
# INFO:root:Case numbers added:
# [2019] SGHC 89
# [2018] SGHC 59
# [2006] 3 SLR(R) 322
# [2015] 5 SLR 295
# INFO:root:2019_SGHC_89 overwritten.
# INFO:root:Repopulating 2019_SGCA_16...
# INFO:root:Case numbers added:
# [2019] SGCA 16
# [2018] SGHC 94
# [2016] SGDC 274
# [2008] 1 SLR(R) 449
# [2016] 1 SLR 334
# [2012] QCA 202
# [2018] 1 SLR 127
# [2018] 2 SLR 249
# [2016] 3 SLR 465
# [2015] 3 SLR 222
# [2008] 1 SLR(R) 824
# [1998] 1 SLR(R) 37
# [2017] 1 SLR 373
# [2017] 2 SLR 850
# [2018] 1 SLR 659
# [2015] 1 SLR 26
# [2015] 2 SLR 1129
# [2017] 1 SLR 173
# [2010] 3 SLR 489
# [1998] 3 SLR(R) 439
# [2018] 5 SLR 1289
# [2007] 2 SLR(R) 334
# [1991] 1 SLR(R) 863
# [1991] 2 SLR(R) 214
# [2017] 2 SLR 1015
# [2014] 3 SLR 299
# [2018] 2 SLR 295
# [2006] 1 SLR(R) 265
# [2007] 4 SLR(R) 753
# [2014] 4 SLR 892
# [2016] 3 SLR 269
# [2018] 3 SLR 1106
# [2018] 3 SLR 1080
# [2014] 2 SLR 998
# [2008] 2 SLR(R) 684
# [1999] 3 SLR(R) 653
# [2017] 5 SLR 904
# [2017] 2 SLR 449
# [2016] 5 SLR 636
# [2014] 4 SLR 1287
# [2008] 1 SLR(R) 824
# [2019] SGCA 16
# WARNING:root:Case numbers could have been added incorrectly to 2019_SGCA_16 (21823 excess char added)
# INFO:root:Repopulating 2019_SGHC_42...
# INFO:root:Case numbers added:
# [2019] SGHC 42
# [2018] SGDC 224
# [2014] 1 SLR 756
# [2014] 2 SLR 998
# [2016] 5 SLR 636
# [2010] 1 SLR 874
# [2018] 5 SLR 799
# [2017] 2 SLR 449
# [2007] 2 SLR(R) 334
# [2016] 4 SLR 1220
# [2006] SGDC 301
# [2004] SGDC 301
# [1992] 1 SLR(R) 523
# [2017] SGHC 285
# [2005] 1 SLR(R) 766
# [2010] 1 SLR 52
# [2015] 3 SLR 1166
# [1919] 2 KB 171
# [1984] 2 WLR 608
# [2011] 4 SLR 217
# [2006] 4 SLR(R) 653
# [1998] WASCA 299
# [2015] WASCA 34
# [2007] 2 SLR(R) 814
# [2017] 2 SLR 68
# [2019] SGHC 42
# WARNING:root:Case numbers could have been added incorrectly to 2019_SGHC_42 (43011 excess char added)
# INFO:root:Repopulating 2019_SGHC_16...
# INFO:root:Case numbers added:
# [2019] SGHC 16
# INFO:root:2019_SGHC_16 overwritten.
# INFO:root:Repopulating 2019_SGHC_29...
# INFO:root:Case numbers added:
# [2019] SGHC 29
# [2018] SGDC 157
# INFO:root:2019_SGHC_29 overwritten.
# INFO:root:Repopulating 2019_SGHC_11...
# INFO:root:Case numbers added:
# [2019] SGHC 11
# [1998] 1 SLR(R) 544
# [2012] 3 SLR 352
# [2000] 3 SLR(R) 198
# [2018] 3 SLR 404
# [2009] 3 SLR(R) 1063
# [2012] 3 SLR 125
# [1978] QB 159
# [2017] SGHC 103
# [1993] 2 SLR(R) 341
# [2000] 1 SLR(R) 117
# INFO:root:2019_SGHC_11 overwritten.
# INFO:root:Repopulating 2019_SGCA_8...
# INFO:root:Case numbers added:
# [2019] SGCA 08
# [2007] 3 SLR(R) 673
# INFO:root:2019_SGCA_8 overwritten.
# INFO:root:Repopulating 2019_SGCA_1...
# INFO:root:Case numbers added:
# [2019] SGCA 1
# [1995] 2 SLR(R) 7
# [2010] 1 SLR 382
# [2016] 1 SLR 753
# [2003] 3 SLR(R) 697
# [2016] 5 SLR 1183
# [2010] 1 SLR 1212
# INFO:root:2019_SGCA_1 overwritten.
# INFO:root:Repopulating 2019_SGHC_27...
# INFO:root:Case numbers added:
# [2019] SGHC 27
# [1997] 3 SLR(R) 649
# [2015] 2 SLR 751
# [2012] 1 SLR 506
# [2007] 1 AC 359
# [2014] SGHC 230
# INFO:root:2019_SGHC_27 overwritten.
# INFO:root:Repopulating 2019_SGHC_18...
# INFO:root:Case numbers added:
# [2019] SGHC 18
# INFO:root:2019_SGHC_18 overwritten.
# INFO:root:Repopulating 2019_SGHC_20...
# INFO:root:Case numbers added:
# [2019] SGHC 20
# [1975] 1 WLR 279
# [1970] AC 567
# [1970] AC 567
# [2015] 4 SLR 474
# [2004] 1 WLR 1466
# [1995] 2 AC 378
# [2003] 2 SLR(R) 33
# [2010] SGCA 4
# [2006] 1 WLR 1476
# [2013] SGCA 36
# [2001] 2 SLR(R) 435
# (1889) 14 App Cas 337
# INFO:root:2019_SGHC_20 overwritten.
# INFO:root:Repopulating 2019_SGCA_6...
# INFO:root:Case numbers added:
# [2019] SGCA 6
# [2017] SGHC 154
# INFO:root:2019_SGCA_6 overwritten.
# INFO:root:Repopulating 2019_SGHC_90...
# INFO:root:Case numbers added:
# [2019] SGHC 90
# [2018] SGMC 73
# [2018] 3 SLR 1048
# [2018] 4 SLR 580
# INFO:root:2019_SGHC_90 overwritten.
# INFO:root:Repopulating 2019_SGHCR_4...
# INFO:root:Case numbers added:
# [2019] SGHCR 4
# [2013] SGHCR 7
# [1991] SGHC 45
# [2005] 3 SLR(R) 389
# [1999] 3 SLR(R) 1156
# INFO:root:2019_SGHCR_4 overwritten.
# INFO:root:Repopulating 2019_SGHC_64...
# INFO:root:Case numbers added:
# [2019] SGHC 64
# [2017] 2 SLR 1015
# [2013] SGHC 235
# [2018] 3 SLR 1048
# [2017] 2 SLR 449
# [2017] 2 SLR 68
# [2014] 4 SLR 892
# [2012] 3 SLR 776
# [2018] SGHC 72
# [2006] 4 SLR(R) 849
# [2018] 5 SLR 799
# [2007] 2 SLR(R) 814
# INFO:root:2019_SGHC_64 overwritten.
# INFO:root:Repopulating 2019_SGHC_8...
# WARNING:root:2019_SGHC_8 not found in SLW.
# INFO:root:Repopulating 2019_SGHC_63...
# INFO:root:Case numbers added:
# [2019] SGHC 63
# [2007] 3 SLR(R) 782
# [2012] 1 SLR 457
# [2013] 3 SLR 801
# INFO:root:2019_SGHC_63 overwritten.
# INFO:root:Repopulating 2019_SGHCR_3...
# INFO:root:Case numbers added:
# [2019] SGHCR 3
# [1989] 2 SLR(R) 105
# [1999] 1 SLR(R) 755
# [2018] 1 SLR 31
# [1989] 1 SLR(R) 689
# [1990] 2 SLR(R) 679
# [1994] 1 SLR(R) 26
# [1996] 3 SLR(R) 583
# [1960] 2 WLR 509
# [1989] 1 SLR(R) 66
# [2018] 1 SLR 50
# [2004] SGDC 31
# INFO:root:2019_SGHCR_3 overwritten.
# INFO:root:Repopulating 2019_SGHC_55...
# INFO:root:Case numbers added:
# [2019] SGHC 55
# INFO:root:2019_SGHC_55 overwritten.
# INFO:root:Repopulating 2019_SGHC_6...
# INFO:root:Case numbers added:
# [2019] SGHC 6
# [1987] AC 460
# [2008] 4 SLR(R) 543
# [2011] 1 SLR 391
# [2017] 2 SLR 265
# [2005] 3 SLR(R) 719
# [2017] 2 SLR 814
# [2007] 1 SLR(R) 377
# [2008] 2 SLR(R) 711
# [2016] 5 SLR 1322
# [2019] SGHC 6
# INFO:root:2019_SGHC_6 overwritten.
# INFO:root:Repopulating 2019_SGHC_52...
# INFO:root:Case numbers added:
# [2019] SGHC 52
# [2013] 4 SLR 193
# [2015] 5 SLR 1187
# [2017] 1 SLR 219
# [2016] 1 SLR 1069
# [2008] 3 SLR(R) 1029
# [1997] 2 SLR(R) 1
# [2007] 1 SLR(R) 132
# [2005] 2 SLR(R) 56
# [1974] 1 AC 821
# INFO:root:2019_SGHC_52 overwritten.
# INFO:root:Repopulating 2019_SGHC_1...
# INFO:root:Case numbers added:
# [2019] SGHC 1
# [2018] SGHC 205
# [2005] 1 SLR(R) 483
# [2016] 1 SLR 174
# [2018] 4 SLR 359
# [1996] 3 SLR(R) 27
# [2012] 4 SLR 1049
# [2017] 4 SLR 1018
# [1995] 2 SLR(R) 407
# [2001] 1 SLR(R) 47
# [2012] 4 SLR 339
# [2001] 1 WLR 1
# [2014] 2 SLR 446
# [2016] 3 SLR 1308
# INFO:root:2019_SGHC_1 overwritten.
# INFO:root:Repopulating 2019_SGHC_39...
# INFO:root:Case numbers added:
# [2019] SGHC 39
# [2001] 2 SLR(R) 435
# [2018] 1 SLR 894
# [2013] 4 SLR 150
# [1994] 3 SLR(R) 1097
# [2013] 4 SLR 886
# [2013] 3 SLR 801
# [2005] 3 SLR(R) 263
# [2013] 4 SLR 308
# [2008] 2 SLR(R) 909
# [2017] 1 SLR 918
# [2000] 2 WLR 1299
# INFO:root:2019_SGHC_39 overwritten.
# INFO:root:Repopulating 2019_SGHC(I)_4...
# INFO:root:Case numbers added:
# [2019] SGHC(I) 4
# [1967] 1 WLR 1421
# INFO:root:2019_SGHC(I)_4 overwritten.
# INFO:root:Repopulating 2019_SGHC(I)_3...
# INFO:root:Case numbers added:
# [2019] SGHC(I) 3
# [2004] 1 AC 919
# [1892] 2 QB 700
# [1994] 1 WLR 1016
# [1999] 2 AC 349
# [1980] QB 677
# INFO:root:2019_SGHC(I)_3 overwritten.
# INFO:root:Repopulating 2019_SGHC_37...
# INFO:root:Case numbers added:
# [2019] SGHC 37
# [2017] 2 SLR 449
# [2017] 2 SLR 1015
# [2018] SGHC 136
# [2018] SGHC 117
# [2005] SGHC 160
# [2015] 5 SLR 122
# [2017] 2 SLR 68
# INFO:root:2019_SGHC_37 overwritten.
# INFO:root:Repopulating 2019_SGHC_30...
# INFO:root:Case numbers added:
# [2019] SGHC 30
# [2013] 1 SLR 733
# [2014] SGHC 157
# [2015] SGDC 270
# [2016] 2 SLR 1067
# [2007] 4 SLR(R) 17
# [2011] 3 SLR 778
# [2016] 1 SLR 992
# [2007] 2 SLR(R) 518
# [2009] 2 SLR(R) 1132
# [2009] NSWSC 1058
# [2013] 4 SLR 529
# [1997] 3 SLR(R) 576
# [2006] 4 SLR 541
# [1999] 6 MLJ 38
# [1953] AC 327
# INFO:root:2019_SGHC_30 overwritten.
# INFO:root:Repopulating 2019_SGHC_53...
# INFO:root:Case numbers added:
# [2019] SGHC 53
# [2018] 4 SLR 801
# [2007] 2 SLR(R) 518
# [1992] 2 SLR(R) 328
# [2010] 3 WLR 941
# [2012] FCA 1002
# [2016] VSC 308
# [2016] FCA 1192
# [2006] 1 Ch 508
# [2014] FCA 1112
# [2014] FCA 711
# [2016] 4 SLR 312
# [2016] 5 SLR 787
# [2019] SGHC 53
# WARNING:root:Case numbers could have been added incorrectly to 2019_SGHC_53 (67846 excess char added)
# INFO:root:Repopulating 2019_SGHC_98...
# INFO:root:Case numbers added:
# [2019] SGHC 98
# [2018] SGDC 229
# [2015] 5 SLR 122
# [2015] 5 SLR 500
# [2018] 5 SLR 852
# [2014] 2 SLR 998
# [2017] 2 SLR 850
# [2017] 1 SLR 373
# [2016] 4 SLR 604
# [2019] SGCA 21
# [2019] SGHC 42
# [2018] 5 SLR 799
# INFO:root:2019_SGHC_98 overwritten.
# INFO:root:Repopulating 2019_SGHC_54...
# INFO:root:Case numbers added:
# [2019] SGHC 54
# INFO:root:2019_SGHC_54 overwritten.
# INFO:root:Repopulating 2019_SGHC_7...
# INFO:root:Case numbers added:
# [2019] SGHC 7
# [2018] 4 SLR 1260
# [1992] 3 SLR(R) 270
# [2018] 1 SLR 317
# [2018] 1 SLR 979
# [2019] SGHC 7
# INFO:root:2019_SGHC_7 overwritten.
# INFO:root:Repopulating 2019_SGHCR_2...
# INFO:root:Case numbers added:
# [2019] SGHCR 2
# [2016] 5 SLR 755
# [2013] 3 SLR 258
# [1990] 2 SLR(R) 348
# [2006] 2 SLR(R) 117
# [2003] 2 SLR(R) 353
# [2001] 2 SLR(R) 821
# [2006] 4 SLR(R) 95
# [2014] 4 SLR 478
# [1977] 1 QB 881
# INFO:root:2019_SGHCR_2 overwritten.
# INFO:root:Repopulating 2019_SGHC_62...
# INFO:root:Case numbers added:
# [2019] SGHC 62
# [2016] 5 SLR 1011
# [2015] 5 SLR 852
# [2010] SCAdjR 771
# [2009] SGHC 156
# [2012] QCA 150
# [2019] SGHC 62
# INFO:root:2019_SGHC_62 overwritten.
# INFO:root:Repopulating 2019_SGHC_65...
# INFO:root:Case numbers added:
# [2019] SGHC 65
# [1998] 3 SLR(R) 1008
# [2017] SGHC 136
# [2015] 5 SLR 295
# [2018] 4 SLR 1003
# [1987] SLR(R) 702
# [2015] HCA 2
# [2018] 2 SLR 84
# [2008] 2 SLR(R) 108
# INFO:root:2019_SGHC_65 overwritten.
# INFO:root:Repopulating 2019_SGHC_9...
# INFO:root:Case numbers added:
# [2019] SGHC 9
# [2018] 1 SLR 317
# [2000] 3 SLR(R) 386
# [2016] 5 SLR 848
# [2014] 2 SLR 318
# [2006] 1 SLR(R) 358
# [2015] 5 SLR 962
# [2012] 1 SLR 457
# [2017] SGHC 229
# [2013] 4 SLR 193
# [2017] 3 SLR 559
# INFO:root:2019_SGHC_9 overwritten.
# INFO:root:Repopulating 2019_SGHC_91...
# INFO:root:Case numbers added:
# [2019] SGHC 91
# [2010] SGHC 195
# [2009] SGHC 66
# [1962] 2 WLR 1228
# [1991] 1 SLR(R) 306
# [1987] SLR(R) 70
# [2013] 3 SLR 710
# [2019] SGHC 91
# WARNING:root:Case numbers could have been added incorrectly to 2019_SGHC_91 (5279 excess char added)
# INFO:root:Repopulating 2019_SGHCR_5...
# INFO:root:Case numbers added:
# [2019] SGHCR 5
# [2017] SGHC 323
# [2008] SGHC 143
# [2016] 2 SLR 489
# [2008] 2 SLR(R) 623
# [2017] 2 SLR 129
# [2018] SGHCR 2
# [1985] 1 MLJ 374
# [2007] 3 SLR(R) 782
# INFO:root:2019_SGHCR_5 overwritten.
# INFO:root:Repopulating 2019_SGHC_31...
# INFO:root:Case numbers added:
# [2019] SGHC 31
# [2018] SGMC 54
# [2018] 4 SLR 580
# [2018] 4 SLR 1294
# [2016] 5 SLR 207
# [2006] 1 SLR(R) 530
# [2016] 1 SLR 334
# [2016] 1 SLR 1370
# [2018] 5 SLR 799
# [2006] 4 SLR 10
# [1966] 2 MLJ 206
# [1959] MLJ 256
# [2008] 1 SLR(R) 601
# [1997] 3 SLR(R) 494
# INFO:root:2019_SGHC_31 overwritten.
# INFO:root:Repopulating 2019_SGHC_36...
# INFO:root:Case numbers added:
# [2019] SGHC 36
# [1904] 2 KB 322
# [1997] 1 SLR(R) 751
# INFO:root:2019_SGHC_36 overwritten.
# INFO:root:Repopulating 2019_SGHC(I)_2...
# INFO:root:Case numbers added:
# [2019] SGHC(I) 2
# [1994] 2 SLR(R) 501
# INFO:root:2019_SGHC(I)_2 overwritten.
# INFO:root:Repopulating 2019_SGHC_38...
# INFO:root:Case numbers added:
# [2019] SGHC 38
# [2013] 2 SLR 340
# [2005] NSWSC 859
# [2004] 3 SLR(R) 1
# [2014] SGHC 147
# [2011] 3 SLR 980
# [2002] 1 SLR(R) 471
# [2011] 1 SLR 552
# [2009] SGHC 223
# [1998] 2 SLR(R) 426
# [2016] SGHC 14
# [2015] SGHC 145
# [2016] 1 SLR 696
# [2017] 1 SLR 654
# [2012] 1 SLR 488
# [2017] 1 SLR 348
# INFO:root:2019_SGHC_38 overwritten.
# INFO:root:Repopulating 2018_SGHCF_22...
# INFO:root:Case numbers added:
# [2018] SGHCF 22
# [2016] 3 SLR 1
# [2004] SGDC 284
# [2005] SGDC 191
# [2003] 4 MLJ 284
# [2013] 4 SLR 193
# [2013] 3 SLR 258
# [2006] 2 SLR(R) 117
# [2015] 1 SLR 797
# [2003] 2 SLR(R) 353
# [1989] 1 SLR(R) 161
# [2015] SGFC 72
# [2018] SGHCF 15
# [2005] 3 SLR(R) 60
# INFO:root:2018_SGHCF_22 overwritten.
# INFO:root:Repopulating 2019_SGHCF_1...
# INFO:root:Case numbers added:
# [2019] SGHCF 1
# [2018] 1 SLR 1015
# [2013] 3 SLR 258
# [2017] SGHCR 15
# [2004] 4 SLR(R) 39
# [2007] SGHC 69
# [2008] SGHC 98
# [2016] 1 SLR 1382
# [2008] SGHC 98
# [2007] SGHC 69
# [2016] 1 SLR 1382
# [2004] 4 SLR(R) 39
# [2017] 1 SLR 654
# [1955] AC 431
# WARNING:root:Case numbers could have been added incorrectly to 2019_SGHCF_1 (1212 excess char added)
# INFO:root:Repopulating 2019_SGHCF_6...
# INFO:root:Case numbers added:
# [2019] SGHCF 6
# [2011] 2 SLR 1157
# [2017] SGCA 34
# [2007] SLR(R) 729
# INFO:root:2019_SGHCF_6 overwritten.
# INFO:root:Repopulating 2018_SGHC_275...
# INFO:root:Case numbers added:
# [2018] SGHC 275
# [2017] 3 SLR 357
# [1997] AC 254
# [1969] 2 QB 158
# [2005] 3 SLR(R) 157
# [1985] 1 WLR 490
# [2015] 5 SLR 1104
# [2011] 1 AC 763
# [2014] 1 SLR 372
# [2003] 3 SLR(R) 1
# [2014] 4 SLR 79
# [2016] 1 SLR 966
# [2015] 3 SLR 488
# [2000] 1 QB 288
# [2007] 3 SLR(R) 86
# [2011] 4 SLR 305
# [2015] 2 SLR 972
# [2017] 2 SLR 129
# [1991] 1 WLR 461
# [2010] 4 SLR 672
# [2011] 3 SLR 414
# [2018] SGCA 81
# [2010] 1 SLR 733
# [1997] AC 254
# [2007] 1 SLR(R) 597
# [2010] 3 SLR 1
# [2011] 4 SLR 739
# [2018] SGHCF 18
# [2013] 4 SLR 629
# [2015] 4 SLR 667
# [2000] 3 SLR(R) 918
# [2016] 1 SLR 217
# [2010] 2 SLR 625
# [2008] 2 SLR(R) 929
# [2015] 3 SLR 973
# [2015] 4 SLR 982
# [1992] HKCFI 182
# INFO:root:2018_SGHC_275 overwritten.
# INFO:root:Repopulating 2018_SGHC_272...
# INFO:root:Case numbers added:
# [2018] SGHC 272
# [2018] SGDC 143
# [2007] 4 SLR(R) 100
# [2014] 3 SLR 562
# [2018] 2 SLR 655
# [1986] SGCA 4
# [2018] 3 SLR 1048
# [2016] 5 SLR 815
# [2011] 2 SLR 146
# [2003] 1 AC 959
# [2003] 1 AC 959
# [1998] 1 WLR 830
# [2014] SGHC 159
# [2009] 2 SLR(R) 786
# INFO:root:2018_SGHC_272 overwritten.
# INFO:root:Repopulating 2019_SGHCF_7...
# INFO:root:Case numbers added:
# [2019] SGHCF 7
# [2019] SGCA 3
# INFO:root:2019_SGHCF_7 overwritten.
# INFO:root:Repopulating 2019_SGHCF_9...
# INFO:root:Case numbers added:
# [2019] SGHCF 9
# [2018] 4 SLR 828
# [2016] 3 SLR 1
# [2008] 2 SLR(R) 702
# INFO:root:2019_SGHCF_9 overwritten.
# INFO:root:Repopulating 2018_SGHC_273...
# INFO:root:Case numbers added:
# [2018] SGHC 273
# [2017] SGHC 73
# [2018] 2 SLR 333
# [2005] 3 SLR(R) 157
# [2007] 1 SLR(R) 453
# [1994] 3 SLR(R) 1064
# [2015] QB 499
# [2018] 4 SLR 1053
# [1968] 1 WLR 1555
# [2003] 2 AC 366
# [1964] 1 WLR 993
# [1958] 1 WLR 815
# [2014] 1 SLR 847
# [2009] VSC 604
# [2007] WASCA 141
# WARNING:root:Case numbers could have been added incorrectly to 2018_SGHC_273 (53871 excess char added)
# INFO:root:Repopulating 2018_SGHC_274...
# INFO:root:Case numbers added:
# [2018] SGHC 274
# [2000] 2 SLR(R) 407
# [2012] 4 SLR 1206
# [2009] 2 SLR(R) 332
# [2018] 1 SLR 363
# [2014] 3 SLR 609
# INFO:root:2018_SGHC_274 overwritten.
# INFO:root:Repopulating 2018_SGHC_280...
# INFO:root:Case numbers added:
# [2018] SGHC 280
# [2013] 2 SLR 715
# [2009] 2 SLR(R) 332
# [2008] 2 SLR(R) 108
# [2014] 3 SLR 1048
# [2002] 2 AC 773
# [2013] 3 SLR 801
# [1996] 1 WLR 1378
# INFO:root:2018_SGHC_280 overwritten.
# INFO:root:Repopulating 2018_SGHC_269...
# INFO:root:Case numbers added:
# [2018] SGHC 269
# [2018] SGDC 182
# [2011] 4 SLR 1
# [2018] 4 SLR 609
# [2017] 4 SLR 1153
# [2007] 2 SLR(R) 334
# [2017] 5 SLR 755
# [2017] 2 SLR 449
# [2008] 1 SLR(R) 1
# [2011] 4 SLR 1156
# [2014] 4 SLR 892
# [2006] 4 SLR(R) 653
# [2008] 2 SLR(R) 684
# [2011] 1 SLR 84
# [2011] 4 SLR 217
# [2008] 4 SLR(R) 879
# [2003] 3 SLR(R) 576
# [2014] 2 SLR 998
# INFO:root:2018_SGHC_269 overwritten.
# INFO:root:Repopulating 2018_SGHC_267...
# INFO:root:Case numbers added:
# [2018] SGHC 267
# [2007] 1 AC 181
# [2010] 4 SLR 801
# [2007] 2 SLR(R) 518
# [2014] SGHC 227
# [2003] 1 AC 1046
# [2014] 2 SLR 1261
# [2016] 3 SLR 1
# [2017] 2 SLR 342
# [1999] 2 SLR(R) 592
# [2017] 4 SLR 1215
# [2005] 3 SLR(R) 60
# INFO:root:2018_SGHC_267 overwritten.
# INFO:root:Repopulating 2018_SGHC_268...
# INFO:root:Case numbers added:
# [2018] SGHC 268
# [2014] 3 SLR 721
# [2018] SGCA 62
# [2017] SGCA 41
# [2011] 3 SLR 1205
# [2011] 4 SLR 791
# [2012] 2 SLR 903
# [2017] 1 SLR 633
# [2004] 1 SLR(R) 550
# [2016] SGCA 11
# [2018] 1 SLR 449
# INFO:root:2018_SGHC_268 overwritten.
# INFO:root:Repopulating 2019_SGHC_25...
# INFO:root:Case numbers added:
# [2019] SGHC 25
# [2018] SGDC 91
# [2000] SGCA 44
# [1969] 2 MLJ 17
# [1995] 4 MLJ 758
# [1986] 1 WLR 1042
# [1981] 2 MLJ 287
# [2016] SGHC 199
# [2018] 2 SLR 1119
# INFO:root:2019_SGHC_25 overwritten.
# INFO:root:Repopulating 2019_SGCA_3...
# INFO:root:Case numbers added:
# [2019] SGCA 3
# [2017] 1 SLR 609
# [2015] 4 SLR 1043
# [2016] 2 SLR 686
# [2011] 4 SLR 1121
# [2016] 4 SLR 674
# [1996] 1 SLR(R) 633
# [2015] 2 SLR 195
# [1999] 2 SLR(R) 385
# [2016] 4 SLR 145
# [2011] 4 SLR 1121
# [2007] 2 SLR(R) 729
# [2012] SGHC 107
# [2013] SGHC 50
# [2016] SGHC 44
# [2007] 3 SLR(R) 520
# [2011] 2 SLR 1157
# [2007] 3 SLR 743
# [2015] SGCA 52
# INFO:root:2019_SGCA_3 overwritten.
# INFO:root:Repopulating 2019_SGCA_4...
# INFO:root:Case numbers added:
# [2019] SGCA 4
# [2017] SGHC 232
# [2010] 1 SLR 1
# [2007] 4 SLR(R) 565
# INFO:root:2019_SGCA_4 overwritten.
# INFO:root:Repopulating 2019_SGHC_22...
# INFO:root:Case numbers added:
# [2019] SGHC 22
# INFO:root:2019_SGHC_22 overwritten.
# INFO:root:Repopulating 2019_SGHC_14...
# INFO:root:Case numbers added:
# [2019] SGHC 14
# [2018] SGDC 130
# [2014] 4 SLR 1287
# [2015] 3 SLR 222
# [2018] 2 SLR 295
# [2016] SGHC 69
# [2003] 3 SLR(R) 178
# [2014] 3 SLR 299
# [2016] SGMC 52
# INFO:root:2019_SGHC_14 overwritten.
# INFO:root:Repopulating 2019_SGHC_13...
# INFO:root:Case numbers added:
# [2019] SGHC 13
# [2017] SGHC 266
# [2018] 2 SLR 616
# [2015] SGHC 192
# [2012] 4 SLR 1267
# [2014] 4 SLR 1208
# [2014] 1 SLR 860
# [2008] 1 AC 1174
# [2008] 1 AC 1
# [2006] 1 SLR(R) 901
# [2008] SGHC 135
# [2018] 2 SLR 159
# [2018] 5 SLR 549
# [2015] 1 SLR 163
# [2015] 4 SLR 667
# [2005] 1 SLR(R) 502
# [2018] 2 SLR 110
# [2018] 1 SLR 317
# [2013] 2 SLR 1154
# [2013] 1 SLR 1
# [2013] 4 SLR 193
# [2009] 3 SLR(R) 518
# INFO:root:2019_SGHC_13 overwritten.
# INFO:root:Repopulating 2019_SGHC_78...
# INFO:root:Case numbers added:
# [2019] SGHC 78
# INFO:root:2019_SGHC_78 overwritten.
# INFO:root:Repopulating 2019_SGCA_13...
# INFO:root:Case numbers added:
# [2019] SGCA 13
# [2018] SGHC 35
# [1957] 1 WLR 582
# [1998] AC 232
# [2017] 2 WLR 1595
# [2017] 2 SLR 492
# INFO:root:2019_SGCA_13 overwritten.
# INFO:root:Repopulating 2019_SGHC_47...
# INFO:root:Case numbers added:
# [2019] SGHC 47
# [2008] 2 SLR(R) 491
# [2008] 2 SLR(R) 491
# [2001] 2 SLR(R) 285
# [2008] 3 SLR(R) 1029
# [2019] SGCA 7
# [2018] 1 SLR 239
# [2018] 1 SLR 239
# [2007] 3 SLR(R) 537
# [2003] 1 SLR(R) 791
# [2000] 3 SLR(R) 594
# [2014] 2 SLR 905
# INFO:root:2019_SGHC_47 overwritten.
# INFO:root:Repopulating 2019_SGCA_14...
# INFO:root:Case numbers added:
# [2019] SGCA 14
# [2003] 3 SLR(R) 556
# [1892] AC 473
# [2018] 1 SLR 76
# [2007] 2 SLR(R) 770
# [1988] 1 SLR(R) 631
# [2002] 1 SLR(R) 326
# [2007] 2 SLR(R) 983
# INFO:root:2019_SGCA_14 overwritten.
# INFO:root:Repopulating 2019_SGHC_40...
# INFO:root:Case numbers added:
# [2019] SGHC 40
# [2019] SGHC 39
# [2009] 3 SLR(R) 689
# [1999] 2 SLR(R) 992
# [2010] 1 SLR 338
# [2013] 4 SLR 176
# [2003] 2 AC 541
# [2018] SGCA 83
# INFO:root:2019_SGHC_40 overwritten.
# INFO:root:Repopulating 2019_SGCA_22...
# INFO:root:Case numbers added:
# [2019] SGCA 22
# [2016] 1 SLR 632
# [1992] 1 SLR(R) 219
# [2005] 4 SLR(R) 582
# [1977] 1 MLJ 174
# [2017] 1 SLR 450
# [2018] SGHC 34
# [2015] 2 SLR 112
# [2017] 1 SLR 748
# [2005] SGHC 176
# [2006] 4 SLR(R) 653
# [1995] 1 SLR(R) 185
# [1998] 3 SLR(R) 679
# [2014] 4 SLR 1287
# [2017] 2 SLR 68
# [2019] SGCA 16
# [2008] 1 SLR(R) 601
# [2005] 1 SLR(R) 611
# INFO:root:2019_SGCA_22 overwritten.
# INFO:root:Repopulating 2019_SGHC_49...
# INFO:root:Case numbers added:
# [2019] SGHC 49
# [2012] 3 SLR 34
# [2008] 1 SLR(R) 601
# [2016] 5 SLR 636
# [2018] SGHC 125
# [2001] 2 SLR(R) 583
# [1996] 3 SLR(R) 444
# [2003] 4 SLR(R) 374
# [2017] 2 SLR 449
# [2006] 4 SLR(R) 849
# [2007] 2 SLR(R) 814
# [2018] 5 SLR 799
# INFO:root:2019_SGHC_49 overwritten.
# INFO:root:Repopulating 2019_SGHC_82...
# INFO:root:Case numbers added:
# [2019] SGHC 82
# [2013] 4 SLR 886
# [2011] 4 SLR 559
# [2013] 4 SLR 193
# [2007] 4 SLR(R) 100
# [2011] 2 SLR 146
# [2018] SGHC 131
# INFO:root:2019_SGHC_82 overwritten.
# INFO:root:Repopulating 2019_SGHC_76...
# INFO:root:Case numbers added:
# [2019] SGHC 76
# [2007] 2 SLR(R) 106
# [1995] 3 SLR(R) 929
# INFO:root:2019_SGHC_76 overwritten.
# INFO:root:Repopulating 2019_SGCA_25...
# INFO:root:Case numbers added:
# [2019] SGCA 25
# [2013] 4 SLR 1
# [2018] SGHC 80
# [2017] 2 SLR 850
# [2019] SGCA 16
# [2015] 1 SLR 26
# [2016] 4 SLR 604
# [2015] 2 SLR 1129
# [2018] 1 SLR 1069
# [2013] 1 SLR 797
# [2011] 2 SLR 1279
# [1999] 1 WLR 347
# [2014] 1 SLR 345
# [2012] 4 SLR 476
# INFO:root:2019_SGCA_25 overwritten.
# INFO:root:Repopulating 2019_SGHC_71...
# INFO:root:Case numbers added:
# [2019] SGHC 71
# [2014] 3 SLR 721
# INFO:root:2019_SGHC_71 overwritten.
# INFO:root:Repopulating 2019_SGHC_85...
# INFO:root:Case numbers added:
# [2019] SGHC 85
# [2012] 3 SLR 172
# [2018] 2 SLR 110
# [2005] 1 SLR(R) 502
# INFO:root:2019_SGHC_85 overwritten.
# INFO:root:Repopulating 2019_SGHC_12...
# INFO:root:Case numbers added:
# [2019] SGHC 12
# [2018] 5 SLR 1068
# INFO:root:2019_SGHC_12 overwritten.
# INFO:root:Repopulating 2019_SGHC_15...
# INFO:root:Case numbers added:
# [2019] SGHC 15
# [2017] SGHC 210
# [2016] 1 SLR 373
# [2016] 1 WLR 4098
# INFO:root:2019_SGHC_15 overwritten.
# INFO:root:Repopulating 2019_SGHC_23...
# INFO:root:Case numbers added:
# [2019] SGHC 23
# INFO:root:2019_SGHC_23 overwritten.
# INFO:root:Repopulating 2019_SGCA_5...
# INFO:root:Case numbers added:
# [2019] SGCA 5
# [2005] 3 SLR(R) 550
# [2004] 1 SLR(R) 671
# [2010] 3 SLR 82
# [1979] 2 WLR 150
# [1910] 1 KB 339
# [1921] 3 KB 110
# [2003] 3 WLR 21
# [1980] 3 WLR 457
# [2018] 2 SLR 129
# [1892] AC 118
# [2018] SGCA 73
# [1924] 1 KB 431
# [1981] 2 WLR 80
# [2003] 4 SLR(R) 1
# [2017] SGDC 178
# INFO:root:2019_SGCA_5 overwritten.
# INFO:root:Repopulating 2019_SGCA_2...
# INFO:root:Case numbers added:
# [2019] SGCA 2
# [2017] SGDC 23
# [2012] 3 SLR 12
# [2017] 5 SLR 1081
# [2017] 1 SLR 373
# [2017] 2 SLR 850
# [2018] 1 SLR 659
# [2016] 4 SLR 604
# [2007] 4 SLR(R) 183
# INFO:root:2019_SGCA_2 overwritten.
# INFO:root:Repopulating 2019_SGHC_24...
# INFO:root:Case numbers added:
# [2019] SGHC 24
# [2018] SGHC 18
# INFO:root:2019_SGHC_24 overwritten.
# INFO:root:Repopulating 2019_SGCA_24...
# INFO:root:Case numbers added:
# [2019] SGCA 24
# [2017] SGHCF 17
# INFO:root:2019_SGCA_24 overwritten.
# INFO:root:Repopulating 2019_SGHC_84...
# INFO:root:Case numbers added:
# [2019] SGHC 84
# [1992] 1 WLR 277
# [2014] 2 SLR 573
# [2006] 1 SLR(R) 634
# [1976] 1 WLR 403
# [2007] 1 SLR(R) 1004
# [2014] 4 SLR 1
# [2009] 2 SLR 385
# [2015] SGHC 222
# INFO:root:2019_SGHC_84 overwritten.
# INFO:root:Repopulating 2019_SGHC_70...
# INFO:root:Case numbers added:
# [2019] SGHC 70
# [2016] 4 SLR 351
# [2005] 2 SLR(R) 613
# [1994] 3 SLR(R) 1013
# [2015] 5 SLR 1322
# [2006] 3 SLR(R) 769
# [2016] 4 MLJ 1
# [2003] 2 SLR(R) 554
# [2016] 2 SLR 944
# [2011] 3 SLR 540
# [2010] 3 SLR 364
# [2013] 4 SLR 308
# [2016] SGHC 28
# [1997] 3 SLR(R) 676
# [2015] 5 SLR 409
# [2000] 3 MLJ 543
# [2013] 4 SLR 1
# [1995] 3 SLR(R) 653
# [2018] 1 SLR 790
# [2008] 4 SLR(R) 165
# [2006] 1 WLR 682
# [2011] 2 SLR 146
# [2016] 4 SLR 521
# [2014] 4 SLR 375
# [2007] 4 SLR(R) 100
# INFO:root:2019_SGHC_70 overwritten.
# INFO:root:Repopulating 2019_SGHC_48...
# INFO:root:Case numbers added:
# [2019] SGHC 48
# [2015] 2 SLR 903
# [2017] 4 SLR 333
# [2016] SGHC 69
# [2018] 2 SLR 1156
# [2015] 1 SLR 470
# [2012] 1 SLR 615
# [2017] 5 SLR 1064
# [1998] 3 SLR(R) 196
# [2019] SGHC 48
# WARNING:root:Case numbers could have been added incorrectly to 2019_SGHC_48 (43152 excess char added)
# INFO:root:Repopulating 2019_SGCA_23...
# INFO:root:Case numbers added:
# [2019] SGCA 23
# [2017] SGHC 19
# [1994] 2 SLR(R) 467
# [2001] 1 SLR(R) 811
# [1995] 1 SLR(R) 279
# [1998] 1 SLR(R) 195
# [1994] SGHC 113
# [1994] SGHC 117
# [2003] 1 SLR(R) 773
# [1997] 1 WLR 1232
# [2004] 3 MLJ 301
# [2013] 2 MLJ 16
# [1992] 3 SLR(R) 497
# [1986] 2 MLJ 395
# [1999] 4 MLJ 669
# [1983] 2 AC 286
# [2016] 1 SLR 1020
# [2002] 2 SLR(R) 633
# [1992] 1 SLR(R) 117
# [2019] SGCA 23
# WARNING:root:Case numbers could have been added incorrectly to 2019_SGCA_23 (89253 excess char added)
# INFO:root:Repopulating 2019_SGHC_77...
# INFO:root:Case numbers added:
# [2019] SGHC 77
# [2001] SGHC 103
# [2014] SGHC 6
# [1903] 1 KB 735
# [2019] SGHC 77
# WARNING:root:Case numbers could have been added incorrectly to 2019_SGHC_77 (13011 excess char added)
# INFO:root:Repopulating 2019_SGHC_83...
# INFO:root:Case numbers added:
# [2019] SGHC 83
# [2007] 2 SLR(R) 814
# [1999] 1 SLR(R) 1022
# [2017] 2 SLR 1015
# [2018] 4 SLR 580
# [2014] 2 SLR 998
# [2018] 5 SLR 799
# [2018] SGHC 134
# [2017] SGHC 188
# INFO:root:2019_SGHC_83 overwritten.
# INFO:root:Repopulating 2019_SGCA_15...
# INFO:root:Case numbers added:
# [2019] SGCA 15
# [2018] SGHC 74
# [2016] 5 SLR 302
# [2014] 3 SLR 1048
# [2018] SGCA 83
# [2010] 1 SLR 874
# [2018] 1 SLR 1015
# [2016] SGHC 113
# [2007] 2 AC 432
# [2011] 3 WLR 1121
# [2007] 1 SLR(R) 265
# [2009] 4 SLR(R) 769
# [2014] 3 SLR 277
# [2008] SGHC 207
# [2007] 2 SLR(R) 417
# [2014] SGHC 17
# [2018] SGHC 74
# INFO:root:2019_SGCA_15 overwritten.
# INFO:root:Repopulating 2019_SGHC_41...
# INFO:root:Case numbers added:
# [2019] SGHC 41
# [2009] 1 SLR(R) 42
# [2016] 5 SLR 590
# [2012] SGHC 43
# [2005] 2 SLR(R) 579
# [2012] 9 MLJ 281
# [1997] 2 SLR(R) 746
# [1969] 2 QB 173
# [2007] 2 SLR(R) 367
# [2003] 1 QB 1556
# [2017] 1 WLR 1991
# [2018] 4 SLR 391
# [2016] 4 SLR 829
# [2017] 2 SLR 94
# [1990] 1 AC 109
# [2004] 2 AC 457
# [2005] 1 AC 610
# [1980] AC 521
# INFO:root:2019_SGHC_41 overwritten.
# INFO:root:Repopulating 2019_SGCA_12...
# INFO:root:Case numbers added:
# [2019] SGCA 12
# [2017] 2 SLR 1015
# INFO:root:2019_SGCA_12 overwritten.
# INFO:root:Repopulating 2019_SGHC_79...
# INFO:root:Case numbers added:
# [2019] SGHC 79
# [1992] 3 SLR(R) 256
# [2018] 2 SLR 557
# [2014] SGHC 125
# [2008] 1 SLR(R) 1
# [2017] SGHC 99
# INFO:root:2019_SGHC_79 overwritten.
# INFO:root:Repopulating 2019_SGHC_46...
# INFO:root:Case numbers added:
# [2019] SGHC 46
# [2018] SGDC 195
# [2008] 2 SLR(R) 61
# [2006] 4 SLR(R) 45
# [2008] 1 SLR(R) 601
# [2012] 3 SLR 34
# [2016] 5 SLR 636
# [1996] 3 SLR(R) 444
# [2006] 4 SLR(R) 45
# [2014] 3 SLR 562
# [1998] 2 SLR(R) 211
# INFO:root:2019_SGHC_46 overwritten.

# %%
# Repopulation statistics
print(len(judgments_without_case_numbers), 'judgment(s) have missing case numbers.')
print(len(badly_repopulated_judgments), 'judgment(s) were not repopulated due to bad repopulation.')
print(len(judgments_not_found_in_slw), 'judgment(s) could not be found in SLW.')
# Out:
# 161 judgment(s) have missing case numbers.
# 20 judgment(s) were not repopulated due to bad repopulation.
# 1 judgment(s) could not be found in SLW.
